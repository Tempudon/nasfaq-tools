# %%
# !pip install requests
# !pip install tzdata
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (2.23.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests) (2021.5.30)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests) (2.10)
# Collecting tzdata
#   Downloading tzdata-2021.2.post0-py2.py3-none-any.whl (339 kB)
#      |████████████████████████████████| 339 kB 2.7 MB/s
# Installing collected packages: tzdata
# Successfully installed tzdata-2021.2.post0

# %%
import sys
import json
import os.path
import requests
import time
from datetime import datetime,timedelta
from time import mktime
#from zoneinfo import ZoneInfo

# for enabling and disabling the subs to view shit which is outdated and not valid anymore
THEORETICAL_VIEWS = False

# from colorama import init
# from colorama import Fore, Style
# init()

HOLO_POI_URL = "https://holoapi.poi.cat/api/v4/channels_report?ids={holo}&metrics=youtube_channel_subscriber,youtube_channel_view&startAt={startDate}&endAt={endDate}"
NASFAQ_URL = "https://nasfaq.biz/api/getStats"

JSON_FILENAME = "holostats.json"


# subs are possibly worth about 10k view for 1k subs
# this doesn't apply anymore but I'm too lazy to scrub it out
SUB_TO_VIEW_VALUE = 10000

# list the holos by their generation according to nasfaq since
# the lists returned by neither server does so
# girls you dont want can just be removed from the list
HOLOS = ["hololive", "sora", "roboco", "miko", "suisei", "azki", 
         "mel", "fubuki", "matsuri", "aki", "haato", 
         "aqua", "shion", "ayame", "choco", "subaru", 
         "mio", "okayu", "korone", 
         "pekora", "rushia", "flare", "noel", "marine", 
         "kanata", "coco", "watame", "towa", "himemoriluna", 
         "lamy", "nene", "botan", "polka", 
         "risu", "moona", "iofi", 
         "calliope", "kiara", "inanis", "gura", "amelia", "irys", 
         "sana", "fauna", "kronii", "mumei", "baelz",
         "ollie", "melfissa", "reine", 
         "ui", "nana", "pochimaru", "ayamy", "nabi"]

# need to ensure we dont get fucked by dumb time fuckery which includes dst
#TIMEZONE = ZoneInfo("Australia/Brisbane")
#values for when adjustments occurs
LOCAL_RESET_HOUR = 13
#nasfaq
LOCAL_ADJUSTMENT_MINUTE = 5
#this is for holopoi
LOCAL_RESET_MINUTE = 0
# 12 hours
REDOWNLOAD_STAT_TIME = 43200
# testHolo = "kanata"

# with open("data_file.json", "w") as write_file:
#     json.dump(data, write_file)
currentTime = int(time.time() * 1e3) 
threeDaysMilliSeconds = 259200000

threeDaysAgoTime = int((currentTime - threeDaysMilliSeconds))
fourDaysMilliSeconds = 345600000

fourDaysAgoTime = int((currentTime - fourDaysMilliSeconds))

response = requests.get(testHoloURL)
statResponseJson = None
if( not os.path.isfile(JSON_FILENAME)):
    print("Creating {filename} and getting getStat".format(filename=JSON_FILENAME))
    res = requests.get(NASFAQ_URL)
    res = res.json()
    statResponseJson = res
    curTime = mktime(datetime.now().timetuple())
    jsonData = {}
    jsonData["lastGrab"] = curTime
    jsonData["stats"] = res
    with open(JSON_FILENAME, "w", encoding="utf-8") as statJSON:
        json.dump(jsonData, statJSON)
else:
    res = None
    with open(JSON_FILENAME, "r+", encoding="utf-8") as statJSON:
        res = json.load(statJSON)
    curTime = mktime(datetime.now().timetuple())
    if (curTime - res["lastGrab"]) > REDOWNLOAD_STAT_TIME:
        print("Updating getStat")
        res = requests.get(NASFAQ_URL)
        res = res.json()
        statResponseJson = res
        jsonData = {}
        jsonData["lastGrab"] = curTime
        jsonData["stats"] = res
        with open(JSON_FILENAME, "w", encoding="utf-8") as statJSON:
            json.dump(jsonData, statJSON)
    else:
        print("Using saved stats")
        statResponseJson = res["stats"]

coinHistory = json.loads(statResponseJson['coinHistory'])

currentDate = datetime.now()
dateFormat = "{month}/{day}/{year}"

currentDateStamp = dateFormat.format(month = currentDate.strftime("%m"), day = currentDate.strftime("%d"), year = currentDate.strftime("%Y"))

holoList = statResponseJson['stats']
poiStatCount ={}

yesterdayAdjustmentTime = coinHistory[-1]['timestamp']
# for tick in reversed(range(len(statResponseJson['coinInfo']['data']['aki']['history']))):
#     pass
#     curTimestamp = statResponseJson['coinInfo']['data']['aki']['history'][tick]['timestamp']
#     curDate = datetime.fromtimestamp(curTimestamp / 1e3)
#     curHour = curDate.hour
#     curMinute = curDate.minute
#     if (curHour == LOCAL_RESET_HOUR and LOCAL_ADJUSTMENT_MINUTE == curDate.minute and LOCAL_ADJUSTMENT_MINUTE == (curDate.minute - 1) and LOCAL_ADJUSTMENT_MINUTE == (curDate.minute + 1) ):
#         yesterdayAdjustmentTime = curTimestamp

yesterdayAdjustmentHistory = {}

# for holo in statResponseJson['coinInfo']['data']:
#     pass
#     history = statResponseJson['coinInfo']['data'][holo]['history']
#     for tick in reversed(range(len(history))):
#         if(history[tick]['timestamp'] == yesterdayAdjustmentTime):
#             pass
#             yesterdayAdjustmentHistory[holo] = history[tick]
for tick in reversed(range(len(coinHistory))):
    pass
    history = coinHistory
    if(history[tick]['timestamp'] == yesterdayAdjustmentTime):
        pass
        yesterdayAdjustmentHistory = history[tick]['data']
todayCoinHistory = {}
for holo in coinHistory[-1]['data']:
    pass
    holoCoin = coinHistory[-1]['data'][holo]
    todayCoinHistory[holo] = holoCoin

# todayCoinHistory = statResponseJson['todayPrices'][-1]["coinInfo"]['data']
# Out:
# https://holoapi.poi.cat/api/v4/channels_report?ids=kanata&metrics=youtube_channel_subscriber,youtube_channel_view&startAt=1633996863778&endAt=1634256063778
# Creating holostats.json and getting getStat

# %%
yesterday = currentDate - timedelta(days=1)
twoDaysAgo = currentDate - timedelta(days=2)
threeDaysAgo = currentDate - timedelta(days=3)
print(yesterday)
print(twoDaysAgo)

for holo in HOLOS:
    if (holo == 'civia'):
        continue
    if(holo == 'kronii'):
      holoPoiUrl = HOLO_POI_URL.format(holo='ouro', startDate=fourDaysAgoTime, endDate=currentTime)
      poiStatReponse = requests.get(holoPoiUrl)
    elif(holo == 'fauna'):
      holoPoiUrl = HOLO_POI_URL.format(holo='ceres', startDate=fourDaysAgoTime, endDate=currentTime)
      poiStatReponse = requests.get(holoPoiUrl)
    elif(holo == 'baelz'):
      holoPoiUrl = HOLO_POI_URL.format(holo='hakos', startDate=fourDaysAgoTime, endDate=currentTime)
      poiStatReponse = requests.get(holoPoiUrl)
    elif(holo == 'luna'):
      holoPoiUrl = HOLO_POI_URL.format(holo='himemoriluna', startDate=fourDaysAgoTime, endDate=currentTime)
      poiStatReponse = requests.get(holoPoiUrl)
    else:
      holoPoiUrl = HOLO_POI_URL.format(holo=holo, startDate=fourDaysAgoTime, endDate=currentTime)
      poiStatReponse = requests.get(holoPoiUrl)

    #print(poiStatReponse.json())
    nasDailySubCount = holoList[holo]['dailySubscriberCount']['data'][-1]
    nasDailyViewCount = holoList[holo]['dailyViewCount']['data'][-1]

    holoPoiStatCount = {}

    yesterday = currentDate - timedelta(days=1)
    twoDaysAgo = currentDate - timedelta(days=2)
    threeDaysAgo = currentDate - timedelta(days=3)
    

    for report in poiStatReponse.json()['reports']:
        pass
        # print(report)
        # print('\n\n\n\n')
        rows = report['rows']
        poiTodayCount = {"time":rows[-1][0], "value":rows[-1][1]}
        poiYesterdayCount = {}
        poiTwoDaysCount ={}
        poiThreeDaysCount ={}
        poiDailyCount = 0

        statCounts = {}
        statCounts['today'] = poiTodayCount

        for row in reversed(range(len(rows)-1)):
            pass
            time = rows[row][0]
            unixTime = time/1e3
            # print(unixTime)
            date = datetime.fromtimestamp(unixTime)
            day = date.day
            hour = date.hour
            minutes = date.minute
            # print(date)
            # print(day == yesterday.day)
            # print(hour == LOCAL_RESET_HOUR)
            # print(minutes == LOCAL_RESET_MINUTE)

            
            if (day == yesterday.day and hour == LOCAL_RESET_HOUR and minutes == LOCAL_RESET_MINUTE):
                poiYesterdayCount = {"time":rows[row][0], "value":rows[row][1]}
                statCounts['yesterday'] = poiYesterdayCount

            elif(day == twoDaysAgo.day and hour == LOCAL_RESET_HOUR and minutes == LOCAL_RESET_MINUTE):
                poiTwoDaysCount = {"time":rows[row][0], "value":rows[row][1]}
                statCounts['twoDays'] = poiTwoDaysCount

            elif(day == threeDaysAgo.day and hour == LOCAL_RESET_HOUR and minutes == LOCAL_RESET_MINUTE):
                poiThreeDaysCount = {"time":rows[row][0], "value":rows[row][1]}
                statCounts['threeDays'] = poiThreeDaysCount

        if (report['kind'] == "youtube_channel_subscriber"):
            pass
            holoPoiStatCount['subs'] = statCounts
        elif (report['kind'] == 'youtube_channel_view'):
            pass
            holoPoiStatCount['views'] = statCounts
    poiStatCount[holo] = holoPoiStatCount
    # break
# Out:
# 2021-10-14 00:01:06.722664
# 2021-10-13 00:01:06.722664

# %%
holoBuy = []
holoSell = []
holoBuySmall = []
holoSellSmall = []
holoSubTick = []
holoSubDown = []

with open('holostats.txt', 'w') as statFile:

    def PrintStats(holo):
        holoPoiStatCount = poiStatCount[holo]

        todayViews = holoPoiStatCount['views']['today']['value']
        yesterdayViews = holoPoiStatCount['views']['yesterday']['value']
        twoDaysViews = holoPoiStatCount['views']['twoDays']['value']
        threeDaysViews = holoPoiStatCount['views']['threeDays']['value']

        todaySubs = holoPoiStatCount['subs']['today']['value']
        yesterdaySubs = holoPoiStatCount['subs']['yesterday']['value']
        twoDaysSubs = holoPoiStatCount['subs']['twoDays']['value']
        threeDaysSubs = holoPoiStatCount['subs']['threeDays']['value']

        dailyViewDifference = todayViews - yesterdayViews + 1
        yesterdayViewDifference = yesterdayViews - twoDaysViews + 1
        twoDaysViewDifference = twoDaysViews - threeDaysViews + 1

        dailySubDifference = todaySubs - yesterdaySubs
        yesterdaySubDifference = yesterdaySubs - twoDaysSubs
        twoDaysSubDifference = twoDaysSubs - threeDaysSubs

        nasWeeklyViewCount = holoList[holo]["weeklyViewCount"]["data"][-1]
        averageViews = int(nasWeeklyViewCount) / 7


        theoreticalSubViews = 0
        theoreticalYesterdaySubViews = 0
        if(dailySubDifference / 1000 != 0):
            theoreticalSubViews = (dailySubDifference / 1000) * SUB_TO_VIEW_VALUE
        if(yesterdaySubDifference / 1000 != 0):
            theoreticalYesterdaySubViews = (yesterdaySubDifference / 1000) * SUB_TO_VIEW_VALUE


        # print(todayViews)
        # print(yesterdayViews)
        # print(dailyViewDifference)

        # print (Fore.BLUE)

        print(holo)

        # print(Style.RESET_ALL)

        holoPoiStatCount=poiStatCount[holo]

        print("Today views - {views}".format(views=todayViews))
        print("Yesterday views - {views}".format(views=yesterdayViews))
        print("Daily difference - {difference}".format(difference=(dailyViewDifference)))
        print("Yesterday daily difference - {difference}".format(difference=(yesterdayViewDifference)))
        print("Day difference - {difference}".format(difference=(dailyViewDifference - yesterdayViewDifference)))
        if(dailyViewDifference != 0):
            if(yesterdayViewDifference != 0):
                difference=((float(dailyViewDifference / yesterdayViewDifference) -1) * 100)
                if(holo=='himemoriluna'):
                  holo='luna'
                if (difference > 15 and dailyViewDifference > 100000):
                  holoBuy.append({"1": holo, "2diff": int(difference), "3": dailyViewDifference, "4":yesterdayViewDifference, "5":twoDaysViewDifference, "6ave": int(averageViews)})
                elif (difference < -15 and dailyViewDifference - yesterdayViewDifference < -100000):
                  holoSell.append({"1": holo, "2diff": int(difference), "3": dailyViewDifference, "4":yesterdayViewDifference, "5":twoDaysViewDifference, "6ave": int(averageViews)})
                elif (difference > 1):
                  holoBuySmall.append({"1": holo, "2diff": int(difference), "3": dailyViewDifference, "4":yesterdayViewDifference, "5":twoDaysViewDifference, "6ave": int(averageViews)})
                elif (difference < -1):
                  holoSellSmall.append({"1": holo, "2diff": int(difference), "3": dailyViewDifference, "4":yesterdayViewDifference, "5":twoDaysViewDifference, "6ave": int(averageViews)})
                print("Daily % difference - {difference}%".format(difference=((float(dailyViewDifference / yesterdayViewDifference) -1) * 100)))
        print("Average weekly views: {average}".format(average=averageViews))

        if(THEORETICAL_VIEWS):
            print("Theoretical daily views with sub views - {views}".format(views=((dailyViewDifference) + theoreticalSubViews)))
            print("Theoretical yesterday daily views with sub views - {views}".format(views=((yesterdayViewDifference) + theoreticalYesterdaySubViews)))
            print("Daily difference with theoretical views - {difference}".format(difference=((dailyViewDifference + theoreticalSubViews) - (yesterdayViewDifference + theoreticalYesterdaySubViews))))
            if(yesterdayViewDifference != 0 and theoreticalYesterdaySubViews != 0):
                print("Daily % difference with theoretical views - {difference}".format(difference=(((float(dailyViewDifference + theoreticalSubViews) / (yesterdayViewDifference + theoreticalYesterdaySubViews)) -1) * 100)))

        print("\nToday subs - {views}".format(views=todaySubs))
        print("Yesterday subs - {views}".format(views=yesterdaySubs))
        print("Daily difference - {difference}".format(difference=(dailySubDifference)))
        if (dailySubDifference > 5000):
          holoSubTick.append({"holo": holo, "subDiff": dailySubDifference})
        print("Yesterday daily difference - {difference}".format(difference=(yesterdaySubDifference)))
        if(dailySubDifference != 0):
            if(yesterdaySubDifference != 0):
                print("Daily % difference - {difference}%".format(difference=((float(dailySubDifference / yesterdaySubDifference) - 1) * 100)))

        print ("\n---------------------------------")


    for holo in poiStatCount:
        PrintStats(holo)
# Out:
# hololive
# Today views - 402063231
# Yesterday views - 401292887
# Daily difference - 770345
# Yesterday daily difference - 867050
# Day difference - -96705
# Daily % difference - -11.153336024450722%
# Average weekly views: 803950.1428571428
#
# Today subs - 1460000
# Yesterday subs - 1460000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# sora
# Today views - 71733059
# Yesterday views - 71733059
# Daily difference - 1
# Yesterday daily difference - 104562
# Day difference - -104561
# Daily % difference - -99.99904362961688%
# Average weekly views: 106108.42857142857
#
# Today subs - 868000
# Yesterday subs - 868000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# roboco
# Today views - 52732212
# Yesterday views - 52679978
# Daily difference - 52235
# Yesterday daily difference - 325746
# Day difference - -273511
# Daily % difference - -83.9644999478121%
# Average weekly views: 125029.14285714286
#
# Today subs - 756000
# Yesterday subs - 756000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# miko
# Today views - 136451494
# Yesterday views - 136451494
# Daily difference - 1
# Yesterday daily difference - 440443
# Day difference - -440442
# Daily % difference - -99.99977295586488%
# Average weekly views: 287228.28571428574
#
# Today subs - 1240000
# Yesterday subs - 1240000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# suisei
# Today views - 159434081
# Yesterday views - 159010703
# Daily difference - 423379
# Yesterday daily difference - 530715
# Day difference - -107336
# Daily % difference - -20.224791083726668%
# Average weekly views: 545121.8571428572
#
# Today subs - 1180000
# Yesterday subs - 1180000
# Daily difference - 0
# Yesterday daily difference - 10000
#
# ---------------------------------
# azki
# Today views - 22575276
# Yesterday views - 22554704
# Daily difference - 20573
# Yesterday daily difference - 17873
# Day difference - 2700
# Daily % difference - 15.106585352207237%
# Average weekly views: 19322.714285714286
#
# Today subs - 523000
# Yesterday subs - 523000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# mel
# Today views - 15210724
# Yesterday views - 15200388
# Daily difference - 10337
# Yesterday daily difference - 9243
# Day difference - 1094
# Daily % difference - 11.835983987882726%
# Average weekly views: 10385.714285714286
#
# Today subs - 612000
# Yesterday subs - 612000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# fubuki
# Today views - 198414543
# Yesterday views - 198414543
# Daily difference - 1
# Yesterday daily difference - 230805
# Day difference - -230804
# Daily % difference - -99.99956673382292%
# Average weekly views: 208471.2857142857
#
# Today subs - 1630000
# Yesterday subs - 1630000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# matsuri
# Today views - 91607286
# Yesterday views - 91607286
# Daily difference - 1
# Yesterday daily difference - 145079
# Day difference - -145078
# Daily % difference - -99.99931072036614%
# Average weekly views: 113468.0
#
# Today subs - 1130000
# Yesterday subs - 1130000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# aki
# Today views - 25648620
# Yesterday views - 25648620
# Daily difference - 1
# Yesterday daily difference - 24334
# Day difference - -24333
# Daily % difference - -99.9958905235473%
# Average weekly views: 62503.57142857143
#
# Today subs - 593000
# Yesterday subs - 593000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# haato
# Today views - 141759734
# Yesterday views - 141696671
# Daily difference - 63064
# Yesterday daily difference - 58371
# Day difference - 4693
# Daily % difference - 8.039951345702478%
# Average weekly views: 53506.142857142855
#
# Today subs - 1280000
# Yesterday subs - 1280000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# aqua
# Today views - 159926458
# Yesterday views - 159926458
# Daily difference - 1
# Yesterday daily difference - 127020
# Day difference - -127019
# Daily % difference - -99.99921272240591%
# Average weekly views: 239197.57142857142
#
# Today subs - 1400000
# Yesterday subs - 1400000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# shion
# Today views - 75838577
# Yesterday views - 75838577
# Daily difference - 1
# Yesterday daily difference - 83174
# Day difference - -83173
# Daily % difference - -99.9987977012047%
# Average weekly views: 183598.42857142858
#
# Today subs - 887000
# Yesterday subs - 887000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# ayame
# Today views - 55033938
# Yesterday views - 54958864
# Daily difference - 75075
# Yesterday daily difference - 69054
# Day difference - 6021
# Daily % difference - 8.719263185333226%
# Average weekly views: 76722.85714285714
#
# Today subs - 1140000
# Yesterday subs - 1140000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# choco
# Today views - 22918987
# Yesterday views - 22918987
# Daily difference - 1
# Yesterday daily difference - 46419
# Day difference - -46418
# Daily % difference - -99.99784570973092%
# Average weekly views: 33786.0
#
# Today subs - 747000
# Yesterday subs - 747000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# subaru
# Today views - 99141316
# Yesterday views - 98826944
# Daily difference - 314373
# Yesterday daily difference - 121117
# Day difference - 193256
# Daily % difference - 159.5614158210656%
# Average weekly views: 343847.5714285714
#
# Today subs - 1150000
# Yesterday subs - 1150000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# mio
# Today views - 66000832
# Yesterday views - 66000832
# Daily difference - 1
# Yesterday daily difference - 241587
# Day difference - -241586
# Daily % difference - -99.99958607044253%
# Average weekly views: 147303.7142857143
#
# Today subs - 862000
# Yesterday subs - 862000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# okayu
# Today views - 131047213
# Yesterday views - 130858363
# Daily difference - 188851
# Yesterday daily difference - 205744
# Day difference - -16893
# Daily % difference - -8.210689011587213%
# Average weekly views: 189842.0
#
# Today subs - 1210000
# Yesterday subs - 1210000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# korone
# Today views - 166816631
# Yesterday views - 166816631
# Daily difference - 1
# Yesterday daily difference - 119171
# Day difference - -119170
# Daily % difference - -99.99916086967467%
# Average weekly views: 222917.42857142858
#
# Today subs - 1700000
# Yesterday subs - 1700000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# pekora
# Today views - 279597948
# Yesterday views - 278921308
# Daily difference - 676641
# Yesterday daily difference - 198479
# Day difference - 478162
# Daily % difference - 240.91314446364603%
# Average weekly views: 431792.14285714284
#
# Today subs - 1740000
# Yesterday subs - 1740000
# Daily difference - 0
# Yesterday daily difference - 10000
#
# ---------------------------------
# rushia
# Today views - 119234996
# Yesterday views - 119234996
# Daily difference - 1
# Yesterday daily difference - 90466
# Day difference - -90465
# Daily % difference - -99.99889461234055%
# Average weekly views: 241989.14285714287
#
# Today subs - 1430000
# Yesterday subs - 1430000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# flare
# Today views - 71488472
# Yesterday views - 71488472
# Daily difference - 1
# Yesterday daily difference - 291497
# Day difference - -291496
# Daily % difference - -99.99965694329616%
# Average weekly views: 179595.42857142858
#
# Today subs - 784000
# Yesterday subs - 784000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# noel
# Today views - 100717603
# Yesterday views - 100606603
# Daily difference - 111001
# Yesterday daily difference - 174839
# Day difference - -63838
# Daily % difference - -36.51244859556506%
# Average weekly views: 189959.42857142858
#
# Today subs - 1330000
# Yesterday subs - 1330000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# marine
# Today views - 254435234
# Yesterday views - 254435234
# Daily difference - 1
# Yesterday daily difference - 141710
# Day difference - -141709
# Daily % difference - -99.99929433349799%
# Average weekly views: 159559.7142857143
#
# Today subs - 1660000
# Yesterday subs - 1660000
# Daily difference - 0
# Yesterday daily difference - 10000
#
# ---------------------------------
# kanata
# Today views - 144760908
# Yesterday views - 144760908
# Daily difference - 1
# Yesterday daily difference - 305217
# Day difference - -305216
# Daily % difference - -99.99967236425232%
# Average weekly views: 248634.14285714287
#
# Today subs - 1060000
# Yesterday subs - 1060000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# coco
# Today views - 175650814
# Yesterday views - 175618955
# Daily difference - 31860
# Yesterday daily difference - 32254
# Day difference - -394
# Daily % difference - -1.2215539157933941%
# Average weekly views: 32771.57142857143
#
# Today subs - 1440000
# Yesterday subs - 1440000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# watame
# Today views - 116177731
# Yesterday views - 116177731
# Daily difference - 1
# Yesterday daily difference - 189562
# Day difference - -189561
# Daily % difference - -99.9994724681107%
# Average weekly views: 188377.0
#
# Today subs - 1070000
# Yesterday subs - 1070000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# towa
# Today views - 66299987
# Yesterday views - 66299987
# Daily difference - 1
# Yesterday daily difference - 197494
# Day difference - -197493
# Daily % difference - -99.99949365550346%
# Average weekly views: 175894.2857142857
#
# Today subs - 834000
# Yesterday subs - 833000
# Daily difference - 1000
# Yesterday daily difference - 1000
# Daily % difference - 0.0%
#
# ---------------------------------
# himemoriluna
# Today views - 39178381
# Yesterday views - 39030415
# Daily difference - 147967
# Yesterday daily difference - 98008
# Day difference - 49959
# Daily % difference - 50.97441025222431%
# Average weekly views: 188336.0
#
# Today subs - 710000
# Yesterday subs - 710000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# lamy
# Today views - 71862801
# Yesterday views - 71862801
# Daily difference - 1
# Yesterday daily difference - 173631
# Day difference - -173630
# Daily % difference - -99.999424065979%
# Average weekly views: 178715.57142857142
#
# Today subs - 833000
# Yesterday subs - 833000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# nene
# Today views - 52507816
# Yesterday views - 52507816
# Daily difference - 1
# Yesterday daily difference - 28096
# Day difference - -28095
# Daily % difference - -99.99644077448747%
# Average weekly views: 48510.857142857145
#
# Today subs - 788000
# Yesterday subs - 788000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# botan
# Today views - 89027686
# Yesterday views - 88751598
# Daily difference - 276089
# Yesterday daily difference - 201007
# Day difference - 75082
# Daily % difference - 37.35292800748233%
# Average weekly views: 188430.42857142858
#
# Today subs - 995000
# Yesterday subs - 995000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# polka
# Today views - 89761882
# Yesterday views - 89761882
# Daily difference - 1
# Yesterday daily difference - 255419
# Day difference - -255418
# Daily % difference - -99.99960848644776%
# Average weekly views: 268624.14285714284
#
# Today subs - 840000
# Yesterday subs - 840000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# risu
# Today views - 32475901
# Yesterday views - 32475901
# Daily difference - 1
# Yesterday daily difference - 10708
# Day difference - -10707
# Daily % difference - -99.9906611878969%
# Average weekly views: 19078.285714285714
#
# Today subs - 538000
# Yesterday subs - 538000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# moona
# Today views - 41332604
# Yesterday views - 41241182
# Daily difference - 91423
# Yesterday daily difference - 66919
# Day difference - 24504
# Daily % difference - 36.61740312915613%
# Average weekly views: 83970.85714285714
#
# Today subs - 884000
# Yesterday subs - 884000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# iofi
# Today views - 13349266
# Yesterday views - 13349266
# Daily difference - 1
# Yesterday daily difference - 6394
# Day difference - -6393
# Daily % difference - -99.9843603378167%
# Average weekly views: 17113.571428571428
#
# Today subs - 470000
# Yesterday subs - 470000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# calliope
# Today views - 187948597
# Yesterday views - 187374337
# Daily difference - 574261
# Yesterday daily difference - 560398
# Day difference - 13863
# Daily % difference - 2.4737775652304173%
# Average weekly views: 497687.4285714286
#
# Today subs - 1730000
# Yesterday subs - 1730000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# kiara
# Today views - 86315784
# Yesterday views - 86315784
# Daily difference - 1
# Yesterday daily difference - 54110
# Day difference - -54109
# Daily % difference - -99.99815191277028%
# Average weekly views: 163864.14285714287
#
# Today subs - 1210000
# Yesterday subs - 1210000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# inanis
# Today views - 69716085
# Yesterday views - 69558234
# Daily difference - 157852
# Yesterday daily difference - 57914
# Day difference - 99938
# Daily % difference - 172.56276547984945%
# Average weekly views: 173688.0
#
# Today subs - 1230000
# Yesterday subs - 1230000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# gura
# Today views - 188591299
# Yesterday views - 187628697
# Daily difference - 962603
# Yesterday daily difference - 230147
# Day difference - 732456
# Daily % difference - 318.25572351583986%
# Average weekly views: 579443.1428571428
#
# Today subs - 3470000
# Yesterday subs - 3470000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# amelia
# Today views - 91246689
# Yesterday views - 91246689
# Daily difference - 1
# Yesterday daily difference - 224947
# Day difference - -224946
# Daily % difference - -99.99955545083952%
# Average weekly views: 176153.7142857143
#
# Today subs - 1480000
# Yesterday subs - 1480000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# irys
# Today views - 18856736
# Yesterday views - 18708988
# Daily difference - 147749
# Yesterday daily difference - 51948
# Day difference - 95801
# Daily % difference - 184.41710941710943%
# Average weekly views: 171517.14285714287
#
# Today subs - 667000
# Yesterday subs - 667000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# sana
# Today views - 5041905
# Yesterday views - 5026624
# Daily difference - 15282
# Yesterday daily difference - 91969
# Day difference - -76687
# Daily % difference - -83.38353140732202%
# Average weekly views: 38830.57142857143
#
# Today subs - 201000
# Yesterday subs - 201000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# fauna
# Today views - 8612714
# Yesterday views - 8612714
# Daily difference - 1
# Yesterday daily difference - 58125
# Day difference - -58124
# Daily % difference - -99.99827956989247%
# Average weekly views: 108161.14285714286
#
# Today subs - 309000
# Yesterday subs - 308000
# Daily difference - 1000
# Yesterday daily difference - 2000
# Daily % difference - -50.0%
#
# ---------------------------------
# kronii
# Today views - 9997720
# Yesterday views - 9724907
# Daily difference - 272814
# Yesterday daily difference - 184442
# Day difference - 88372
# Daily % difference - 47.91316511423644%
# Average weekly views: 195442.57142857142
#
# Today subs - 464000
# Yesterday subs - 463000
# Daily difference - 1000
# Yesterday daily difference - 4000
# Daily % difference - -75.0%
#
# ---------------------------------
# mumei
# Today views - 7187385
# Yesterday views - 7157373
# Daily difference - 30013
# Yesterday daily difference - 36037
# Day difference - -6024
# Daily % difference - -16.71615284291145%
# Average weekly views: 78984.28571428571
#
# Today subs - 364000
# Yesterday subs - 363000
# Daily difference - 1000
# Yesterday daily difference - 2000
# Daily % difference - -50.0%
#
# ---------------------------------
# baelz
# Today views - 9567581
# Yesterday views - 9536549
# Daily difference - 31033
# Yesterday daily difference - 43324
# Day difference - -12291
# Daily % difference - -28.369956606038226%
# Average weekly views: 178677.0
#
# Today subs - 304000
# Yesterday subs - 303000
# Daily difference - 1000
# Yesterday daily difference - 1000
# Daily % difference - 0.0%
#
# ---------------------------------
# ollie
# Today views - 33312336
# Yesterday views - 33108196
# Daily difference - 204141
# Yesterday daily difference - 378900
# Day difference - -174759
# Daily % difference - -46.12272367379256%
# Average weekly views: 133267.57142857142
#
# Today subs - 852000
# Yesterday subs - 851000
# Daily difference - 1000
# Yesterday daily difference - 2000
# Daily % difference - -50.0%
#
# ---------------------------------
# melfissa
# Today views - 8145210
# Yesterday views - 8145210
# Daily difference - 1
# Yesterday daily difference - 21184
# Day difference - -21183
# Daily % difference - -99.99527945619336%
# Average weekly views: 17485.571428571428
#
# Today subs - 393000
# Yesterday subs - 393000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# reine
# Today views - 23242926
# Yesterday views - 23148714
# Daily difference - 94213
# Yesterday daily difference - 46535
# Day difference - 47678
# Daily % difference - 102.45621575158484%
# Average weekly views: 64456.71428571428
#
# Today subs - 499000
# Yesterday subs - 499000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# ui
# Today views - 31015811
# Yesterday views - 31015811
# Daily difference - 1
# Yesterday daily difference - 42794
# Day difference - -42793
# Daily % difference - -99.99766322381643%
# Average weekly views: 47693.28571428572
#
# Today subs - 610000
# Yesterday subs - 610000
# Daily difference - 0
# Yesterday daily difference - 1000
#
# ---------------------------------
# nana
# Today views - 17234385
# Yesterday views - 17234385
# Daily difference - 1
# Yesterday daily difference - 19250
# Day difference - -19249
# Daily % difference - -99.9948051948052%
# Average weekly views: 19535.85714285714
#
# Today subs - 282000
# Yesterday subs - 282000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# pochimaru
# Today views - 7396677
# Yesterday views - 7396677
# Daily difference - 1
# Yesterday daily difference - 2596
# Day difference - -2595
# Daily % difference - -99.96147919876734%
# Average weekly views: 10472.0
#
# Today subs - 197000
# Yesterday subs - 197000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------
# ayamy
# Today views - 1290473
# Yesterday views - 1289495
# Daily difference - 979
# Yesterday daily difference - 1923
# Day difference - -944
# Daily % difference - -49.08996359854394%
# Average weekly views: 3214.0
#
# Today subs - 48800
# Yesterday subs - 48800
# Daily difference - 0
# Yesterday daily difference - 100
#
# ---------------------------------
# nabi
# Today views - 2067379
# Yesterday views - 2067379
# Daily difference - 1
# Yesterday daily difference - 4108
# Day difference - -4107
# Daily % difference - -99.97565725413826%
# Average weekly views: 4868.285714285715
#
# Today subs - 307000
# Yesterday subs - 307000
# Daily difference - 0
# Yesterday daily difference - 0
#
# ---------------------------------

# %%
for i in sorted(holoBuy, key=lambda k: k['2diff'], reverse=True):
  if(i["4"] > i["5"]):
    overbuy = "\033[1;32;1m"
  else:
    overbuy = "\033[1;31;1m"
  if(i["3"]/i["5"] < 1):
    overbuy = overbuy + "*"
  print(overbuy + i["1"] + "      \t Diff: " + str(i["2diff"]) + "   \tTodays: " + str(i["3"]) + "     \tYest: " + str(i["4"]) + "       \t2D: " + str(i["5"]) + "         \tAve: " + str(i["6ave"]))
# Out:
# gura      	 Diff: 318   	Todays: 962603     	Yest: 230147       	2D: 253724         	Ave: 579443
# pekora      	 Diff: 240   	Todays: 676641     	Yest: 198479       	2D: 440093         	Ave: 431792
# *irys      	 Diff: 184   	Todays: 147749     	Yest: 51948       	2D: 172434         	Ave: 171517
# *inanis      	 Diff: 172   	Todays: 157852     	Yest: 57914       	2D: 411228         	Ave: 173688
# *subaru      	 Diff: 159   	Todays: 314373     	Yest: 121117       	2D: 337769         	Ave: 343847
# *luna      	 Diff: 50   	Todays: 147967     	Yest: 98008       	2D: 188796         	Ave: 188336
# *kronii      	 Diff: 47   	Todays: 272814     	Yest: 184442       	2D: 399546         	Ave: 195442
# botan      	 Diff: 37   	Todays: 276089     	Yest: 201007       	2D: 205175         	Ave: 188430

# %%
for i in sorted(holoBuySmall, key=lambda k: k['2diff'], reverse=True):
  if(i["4"] > i["5"]):
    overbuy = "\033[1;32;1m"
  else:
    overbuy = "\033[1;31;1m"
  if(i["3"]/i["5"] < 1):
    overbuy = overbuy + "*"
  print(overbuy + i["1"] + "      \t Diff: " + str(i["2diff"]) + "   \tTodays: " + str(i["3"]) + "     \tYest: " + str(i["4"]) + "       \t2D: " + str(i["5"]) + "         \tAve: " + str(i["6ave"]))
# Out:
# reine      	 Diff: 102   	Todays: 94213     	Yest: 46535       	2D: 89361         	Ave: 64456
# moona      	 Diff: 36   	Todays: 91423     	Yest: 66919       	2D: 76409         	Ave: 83970
# azki      	 Diff: 15   	Todays: 20573     	Yest: 17873       	2D: 18728         	Ave: 19322
# mel      	 Diff: 11   	Todays: 10337     	Yest: 9243       	2D: 9836         	Ave: 10385
# haato      	 Diff: 8   	Todays: 63064     	Yest: 58371       	2D: 61551         	Ave: 53506
# ayame      	 Diff: 8   	Todays: 75075     	Yest: 69054       	2D: 71223         	Ave: 76722
# calliope      	 Diff: 2   	Todays: 574261     	Yest: 560398       	2D: 444596         	Ave: 497687

# %%
for i in sorted(holoSell, key=lambda k: k['2diff']):
  if(i["4"] > i["5"]):
    overbuy = "\033[1;32;1m"
  else:
    overbuy = "\033[1;31;1m"
  if(i["3"]/i["5"] > 1):
    overbuy = overbuy + "*"
  print(overbuy + i["1"] + "      \t Diff: " + str(i["2diff"]) + "   \tTodays: " + str(i["3"]) + "     \tYest: " + str(i["4"]) + "       \t2D: " + str(i["5"]) + "         \tAve: " + str(i["6ave"]))
# Out:
# sora      	 Diff: -99   	Todays: 1     	Yest: 104562       	2D: 87121         	Ave: 106108
# miko      	 Diff: -99   	Todays: 1     	Yest: 440443       	2D: 338410         	Ave: 287228
# fubuki      	 Diff: -99   	Todays: 1     	Yest: 230805       	2D: 124314         	Ave: 208471
# matsuri      	 Diff: -99   	Todays: 1     	Yest: 145079       	2D: 64937         	Ave: 113468
# aqua      	 Diff: -99   	Todays: 1     	Yest: 127020       	2D: 136854         	Ave: 239197
# mio      	 Diff: -99   	Todays: 1     	Yest: 241587       	2D: 48912         	Ave: 147303
# korone      	 Diff: -99   	Todays: 1     	Yest: 119171       	2D: 315376         	Ave: 222917
# flare      	 Diff: -99   	Todays: 1     	Yest: 291497       	2D: 274171         	Ave: 179595
# marine      	 Diff: -99   	Todays: 1     	Yest: 141710       	2D: 145423         	Ave: 159559
# kanata      	 Diff: -99   	Todays: 1     	Yest: 305217       	2D: 187564         	Ave: 248634
# watame      	 Diff: -99   	Todays: 1     	Yest: 189562       	2D: 357523         	Ave: 188377
# towa      	 Diff: -99   	Todays: 1     	Yest: 197494       	2D: 174809         	Ave: 175894
# lamy      	 Diff: -99   	Todays: 1     	Yest: 173631       	2D: 158738         	Ave: 178715
# polka      	 Diff: -99   	Todays: 1     	Yest: 255419       	2D: 311761         	Ave: 268624
# amelia      	 Diff: -99   	Todays: 1     	Yest: 224947       	2D: 275003         	Ave: 176153
# roboco      	 Diff: -83   	Todays: 52235     	Yest: 325746       	2D: 91980         	Ave: 125029
# *ollie      	 Diff: -46   	Todays: 204141     	Yest: 378900       	2D: 168823         	Ave: 133267
# suisei      	 Diff: -20   	Todays: 423379     	Yest: 530715       	2D: 423407         	Ave: 545121

# %%
for i in sorted(holoSellSmall, key=lambda k: k['2diff']):
  if(i["4"] > i["5"]):
    overbuy = "\033[1;32;1m"
  else:
    overbuy = "\033[1;31;1m"
  if(i["3"]/(i["5"]+1) > 1):
    overbuy = overbuy + "*"
  print(overbuy + i["1"] + "      \t Diff: " + str(i["2diff"]) + "   \tTodays: " + str(i["3"]) + "     \tYest: " + str(i["4"]) + "       \t2D: " + str(i["5"]) + "         \tAve: " + str(i["6ave"]))
# Out:
# aki      	 Diff: -99   	Todays: 1     	Yest: 24334       	2D: 46241         	Ave: 62503
# shion      	 Diff: -99   	Todays: 1     	Yest: 83174       	2D: 309359         	Ave: 183598
# choco      	 Diff: -99   	Todays: 1     	Yest: 46419       	2D: 16466         	Ave: 33786
# rushia      	 Diff: -99   	Todays: 1     	Yest: 90466       	2D: 310310         	Ave: 241989
# nene      	 Diff: -99   	Todays: 1     	Yest: 28096       	2D: 145537         	Ave: 48510
# risu      	 Diff: -99   	Todays: 1     	Yest: 10708       	2D: 11245         	Ave: 19078
# iofi      	 Diff: -99   	Todays: 1     	Yest: 6394       	2D: 8803         	Ave: 17113
# kiara      	 Diff: -99   	Todays: 1     	Yest: 54110       	2D: 259080         	Ave: 163864
# fauna      	 Diff: -99   	Todays: 1     	Yest: 58125       	2D: 191671         	Ave: 108161
# melfissa      	 Diff: -99   	Todays: 1     	Yest: 21184       	2D: 4958         	Ave: 17485
# ui      	 Diff: -99   	Todays: 1     	Yest: 42794       	2D: 45169         	Ave: 47693
# nana      	 Diff: -99   	Todays: 1     	Yest: 19250       	2D: 19892         	Ave: 19535
# pochimaru      	 Diff: -99   	Todays: 1     	Yest: 2596       	2D: 2602         	Ave: 10472
# nabi      	 Diff: -99   	Todays: 1     	Yest: 4108       	2D: 3833         	Ave: 4868
# *sana      	 Diff: -83   	Todays: 15282     	Yest: 91969       	2D: 11282         	Ave: 38830
# ayamy      	 Diff: -49   	Todays: 979     	Yest: 1923       	2D: 4090         	Ave: 3214
# noel      	 Diff: -36   	Todays: 111001     	Yest: 174839       	2D: 193168         	Ave: 189959
# baelz      	 Diff: -28   	Todays: 31033     	Yest: 43324       	2D: 191527         	Ave: 178677
# mumei      	 Diff: -16   	Todays: 30013     	Yest: 36037       	2D: 167884         	Ave: 78984
# *hololive      	 Diff: -11   	Todays: 770345     	Yest: 867050       	2D: 761814         	Ave: 803950
# okayu      	 Diff: -8   	Todays: 188851     	Yest: 205744       	2D: 273247         	Ave: 189842
# *coco      	 Diff: -1   	Todays: 31860     	Yest: 32254       	2D: 31040         	Ave: 32771

# %%
holoSubTick
# Out:
# []

# %%
for item in holoSubTick:
  for ele in holoBuy:
    if (item["holo"] == ele["1"]):
      print(item["holo"])
